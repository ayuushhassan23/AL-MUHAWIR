# %%
print("hello")
# Out:
# hello

# %%
# %pwd
# Out:
# 'C:\\Users\\aisha\\Desktop\\al-muhawir\\AL-MUHAWIR'

# %%
import os 
os.chdir("../")

# %%
# %pwd
# Out:
# 'C:\\Users\\aisha\\Desktop\\al-muhawir'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\aisha\Desktop\al-muhawir\AL-MUHAWIR

# %%
def load_pdf_file(data):
    loader= DirectoryLoader(data,
                            glob="*.pdf",
                            loader_cls=PyPDFLoader)

    documents=loader.load()

    return documents

# %%
os.chdir('C:/Users/aisha/Desktop/al-muhawir/AL-MUHAWIR')

# %%
extracted_data = load_pdf_file(data='DATA')

# %%
extracted_data
# Out:
# [Document(metadata={'producer': 'Skia/PDF m133', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0', 'creationdate': '2025-02-16T17:39:49+00:00', 'title': 'المختصر في تفسير القرآن الكريم - جـ ١', 'moddate': '2025-02-16T17:39:49+00:00', 'source': 'DATA\\المختصر في تفسير القرآن الكريم - جـ ١.pdf', 'total_pages': 832, 'page': 0, 'page_label': '1'}, page_content=')ﻣﺠﻤﻮﻋﺔ ﻣﻦ اﻟﻤﺆﻟﻔﯿﻦاﻟﻤﺨﺘﺼﺮ ﻓﻲ ﺗﻔﺴﯿﺮ اﻟﻘﺮآن اﻟﻜﺮﯾﻢ   \n اﻟﺘﻔﺴﯿﺮاﻟﻘﺴﻢ:\n اﻟﻤﺨﺘﺼﺮ ﻓﻲ ﺗﻔﺴﯿﺮ اﻟﻘﺮآن اﻟﻜﺮﯾﻢ:اﻟﻜﺘﺎب\n ﺟﻤﺎﻋﺔ ﻣﻦ ﻋﻠﻤﺎء اﻟﺘﻔﺴﯿﺮ:ﺗﺼﻨﯿﻒ\n ﻣﺮﻛﺰ ﺗﻔﺴﯿﺮ ﻟﻠﺪراﺳﺎت اﻟﻘﺮآﻧﯿﺔ:إﺷﺮاف\n ھـ1436 ، اﻟﺜﺎﻟﺜﺔ:اﻟﻄﺒﻌﺔ\n617 :ﻋﺪد اﻟﺼﻔﺤﺎت\n[ﺗﺮﻗﯿﻢ اﻟﻜﺘﺎب ﻣﻮاﻓﻖ ﻟﻠﻤﻄﺒﻮع]\n1437 رﺑﯿﻊ اﻵﺧﺮ15 :ﺗﺎرﯾﺦ اﻟﻨﺸﺮ ﺑﺎﻟﺸﺎﻣﻠﺔ'),
# ...

# %%
#Split the Data into Text Chunks
def text_split(extracted_data):
    text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150,separators=["\n\n", "\n", "•", "،", ".", "؟", " "])
    text_chunks=text_splitter.split_documents(extracted_data)
    return text_chunks

# %%
text_chunks=text_split(extracted_data)
print("Length of Text Chunks", len(text_chunks))
# Out:
# Length of Text Chunks 1900

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
def download_hugging_face_embeddings():
    embeddings2=HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")  #this model return 384 dimensions
    return embeddings2

# %%
embeddings2 =download_hugging_face_embeddings()

# %%
query_result = embeddings2.embed_query("وجعلنا من الماء كل شيئ حي")
print("Length", len(query_result))
# Out:
# Length 384

# %%
query_result
# Out:
# [0.10405480116605759,
#  0.14544790983200073,
#  0.05323982238769531,
#  -0.09133332222700119,
#  -0.042629871517419815,
#  -0.3850495517253876,
#  0.20051859319210052,
#  -0.05130235105752945,
#  -0.14672453701496124,
#  0.05545087903738022,
#  0.1129566878080368,
#  -0.12413589656352997,
#  -0.15050171315670013,
#  0.040588732808828354,
#  -0.05227939784526825,
#  0.1772453933954239,
#  -0.1079624816775322,
#  -0.1864202618598938,
#  -0.3387225270271301,
#  -0.04794865474104881,
#  0.15705233812332153,
#  0.2744542360305786,
#  -0.3611234426498413,
#  0.008829843252897263,
#  0.1407817155122757,
#  0.032830625772476196,
#  -0.5221898555755615,
#  -0.0262601375579834,
#  0.2878209054470062,
#  -0.2861546277999878,
#  0.010449902154505253,
#  -0.2619551420211792,
#  0.21772871911525726,
#  -0.21100880205631256,
#  -0.024609988555312157,
#  0.14576739072799683,
#  0.11059274524450302,
#  0.053994275629520416,
#  -0.3473318815231323,
#  -0.1978335976600647,
#  -0.22309322655200958,
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
print("PINECONE:", os.environ.get("PINECONE_API_KEY"))
print("OPENAI:", os.environ.get("OPENAI_API_KEY"))
# Out:
# PINECONE: pcsk_3SB3Qm_M5pUAApBpMR9p1dNAuq5FHsKQBSGYXFvUSd5DhDfcj12oK8eF54XUFTQNu4kvdX
# OPENAI: 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

# %%
import os
print("PINECONE:", os.environ.get("PINECONE_API_KEY"))
print("OPENAI:", os.environ.get("OPENAI_API_KEY"))
# Out:
# PINECONE: pcsk_3SB3Qm_M5pUAApBpMR9p1dNAuq5FHsKQBSGYXFvUSd5DhDfcj12oK8eF54XUFTQNu4kvdX
# OPENAI: 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

# %%
pinecone_API=os.environ.get('pinecone_API')

# %%
import os
os.environ["PINECONE_API_KEY"] = "pcsk_3SB3Qm_M5pUAApBpMR9p1dNAuq5FHsKQBSGYXFvUSd5DhDfcj12oK8eF54XUFTQNu4kvdX"

# %%
from pinecone import Pinecone, ServerlessSpec
from langchain_pinecone import PineconeVectorStore
from langchain.embeddings import HuggingFaceEmbeddings
import os


pinecone_api_key = "pcsk_3SB3Qm_M5pUAApBpMR9p1dNAuq5FHsKQBSGYXFvUSd5DhDfcj12oK8eF54XUFTQNu4kvdX"
pinecone_env = "us-east-1"

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
)

pc = Pinecone(api_key=pinecone_api_key)

index_name = "al-muhawir"
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region=pinecone_env)
    )

docsearch = PineconeVectorStore.from_documents(
    documents=text_chunks,   
    index_name=index_name,
    embedding=embeddings,
    pinecone_api_key=pinecone_api_key,

)

# %%
docsearch

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retriever.invoke("الحمدلله")
# Out:
# [Document(id='f653aff1-a0dc-498a-a32b-e7701da15b5e', metadata={'creationdate': '2025-02-16T17:39:49+00:00', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0', 'moddate': '2025-02-16T17:39:49+00:00', 'page': 629.0, 'page_label': '630', 'producer': 'Skia/PDF m133', 'source': 'DATA\\المختصر في تفسير القرآن الكريم - جـ ١.pdf', 'title': 'المختصر في تفسير القرآن الكريم - جـ ١', 'total_pages': 832.0}, page_content='• اﺳﺘﺴﻼم اﻟﻜﻮن لله واﻧﻘﯿﺎده ﻷﻣﺮه ﺳﺒﺤﺎﻧﮫ ﺑﻜﻞ ﻣﺎ ﻓﯿﮫ'),
# ...

# %%
openai_API= "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"

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain_openai import OpenAI
llm = OpenAI(temperature=0.4, max_tokens=500)

# %%
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
from langchain_openai import ChatOpenAI
import os


os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_BASE_URL"] = "https://openrouter.ai/api/v1"

llm = ChatOpenAI(
    model="meta-llama/llama-3-8b-instruct",
    temperature=0.4,
    max_tokens=500
)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    "أنت مساعد ذكي ومتخصص في الإجابة على الأسئلة بناءً على المراجع التالية. "
    "استخدم السياق المقدم فقط للإجابة، وإذا لم تجد الإجابة فيه فقل ببساطة 'لا أعرف'. "
    "أجب باللغة العربية الفصحى، في حدود ثلاث جمل، وبأسلوب واضح ومفهوم."
    "\n\n"
    "{context}"
)


prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# %%
document_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, document_chain)

# %%
response = rag_chain.invoke({"input": "ما معنى الصراط المستقيم؟"})
print(response["answer"])
# Out:
# الصراط المستقيم هو مفهوم ديني يأتي من القرآن الكريم، ويعني "الطريق المستقيم" أو "المركز"، وهو يرمز إلى الطريق الذي يأخذ الإنسان فيه من الله إلى الله، أو من الخير إلى الخير، بدون انحراف أو عثرة.
#
# في القرآن، يصف الصراط المستقيم بأنها الطريق التي تليق بالخلق الإنساني، والذي يجب أن يأخذهم من الله إلى الله، بدون انحراف أو عثرة، وذلك لأنها الطريق التي تليق بالخلق الإنساني، والذي يجب أن يأخذهم من الله إلى الله، بدون انحراف أو عثرة.
#
# في هذا السياق، يرمز الصراط المستقيم إلى الطريق الذي يجب أن يأخذ الإنسان فيه ليكون قريباً من الله، والذي يجب أن يأخذهم من الله إلى الله، بدون انحراف أو عثرة.

# %%
response = rag_chain.invoke({"input": " ما دور البرد؟"})
print(response["answer"])
# Out:
# لا أعرف. لا يوجد ذكر لالبرد في النص.

# %%
response = rag_chain.invoke({"input": "من يستحق الثناء وحده؟"})
print(response["answer"])
# Out:
# من acuerdo مع النص، يستحق الثناء وحده الله تعالى، ففي النص يقول: "اﻟﺪاﻋﯿﺔ إﻟﻰ ﷲ ﺗﻌﺎﻟﻰ ﻟﯿﺲ ﻣﺴﺆوﻻً ﻋﻦ ﻣﺤﺎﺳﺒﺔ أﺣﺪ"، مما يشير إلى أن الثناء يخص الله تعالى وحده.

# %%
response = rag_chain.invoke({"input": "ما معني ظل وجهه مسودّاً"})
print(response["answer"])
# Out:
# لا أعرف.
